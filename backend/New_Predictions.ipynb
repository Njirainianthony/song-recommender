# %%
from pathlib import Path
import joblib
import pandas as pd

# %%
# Get sample datasets
BASE_DIR = Path.cwd()

voyage_df = pd.DataFrame(
    joblib.load(BASE_DIR / "debug/6Db1zZcoO7JPczkjjU4vuX" / "songs.pkl")
)

velocity_df = pd.DataFrame(
    joblib.load(BASE_DIR / "debug/64wkinQzeyoBls7ES3RD6Z" / "songs.pkl")
)

dorcas_df = pd.DataFrame(
    joblib.load(BASE_DIR / "debug/6i48HFUuW5SYSskpGlR9Tr" / "songs.pkl")
)

# %%
dorcas_df.head()
# Out:
#                  track_id        artists  \
# 0  05ABOPiW13nqIedJfqmfPM     Tate McRae
# 1  2QQGGz91ZdJatpu5MeWw6R  Vacation Club
# 2  5bYlb2eYDVTuuWZm4jNO3a   Jessie Murph
# 3  7BkmcSikTCB6rx5yrUrzhc           bntm
# 4  75u9uswC5UMdtv4SQ3xSYf    Nicki Minaj
#
#                                       album_name  \
# 0                                     rubberband
# 1               i don't wanna lose you right now
# 2                                   Sex Hysteria
# 3                        When She Holds Me Right
# 4  The Pinkprint (International Deluxe Explicit)
#
#                          track_name  popularity  duration_ms explicit  \
# 0                        rubberband           0       147713    False
# 1  i don't wanna lose you right now          11       200814    False
# 2                      Sex Hysteria          61       178731     True
# 3           When She Holds Me Right          16       215359    False
# ...
