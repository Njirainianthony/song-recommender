# %%
from pathlib import Path
import joblib
import pandas as pd

# %%
# Get sample datasets
BASE_DIR = Path.cwd()

voyage_df = pd.DataFrame(
    joblib.load(BASE_DIR / "debug/6Db1zZcoO7JPczkjjU4vuX" / "songs.pkl")
)

velocity_df = pd.DataFrame(
    joblib.load(BASE_DIR / "debug/64wkinQzeyoBls7ES3RD6Z" / "songs.pkl")
)

# %%
# The voyage of 67 playlist
voyage_df.head()
# Out:
#                  track_id                                      artists  \
# 0  1B2wrYVrPtd3CcrYwUwmPE  Justin Bieber, Brandon Love, Chandler Moore
# 1  7ciVByPgRrzDHnSuLiQ7Ju                           Audiomarc, Nasty C
# 2  21vc2kQZMS00cAyNT82a1M        ¥$, Kanye West, Ty Dolla $ign, Bump J
# 3  24lORMRGMv9sXpZJdN1PVm                   Dreezy, 6LACK, Kodak Black
# 4  5hzrmJKIS2CHmvlUWkdlYy                                 Joyner Lucas
#
#                          album_name  \
# 0                          Freedom.
# 1       Audio Czzle (feat. Nasty C)
# 2                          VULTURES
# 3  Spar (feat. 6LACK & Kodak Black)
# 4                         Seventeen
#
#                                           track_name  popularity  duration_ms  \
# 0  All She Wrote (feat. Brandon Love & Chandler M...          38       234400
# 1                        Audio Czzle (feat. Nasty C)          34       274000
# 2                                           VULTURES           1       237534
# 3                   Spar (feat. 6LACK & Kodak Black)          44       231194
# 4                                          Seventeen          51       205925
#
#   explicit danceability energy   key  ...  mode speechiness acousticness  \
# 0    False         None   None  None  ...  None        None         None
# 1     True         None   None  None  ...  None        None         None
# 2     True         None   None  None  ...  None        None         None
# 3     True         None   None  None  ...  None        None         None
# 4     True         None   None  None  ...  None        None         None
#
#   instrumentalness liveness valence tempo time_signature track_genre  \
# 0             None     None    None  None           None         NaN
# 1             None     None    None  None           None         NaN
# 2             None     None    None  None           None         NaN
# 3             None     None    None  None           None         NaN
# 4             None     None    None  None           None         NaN
#
#   track_youtube_id
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
#
# [5 rows x 21 columns]

# %%
velocity_df.head()
# Out:
#                  track_id                  artists  \
# 0  1UyDQh3HBJwL6IxR9mXipZ  DREAMDNVR, Boy In Space
# 1  5SehvGGC53A7SZKCLXQcyt        Twenty One Pilots
# 2  2Fjz5ZC5BvFdCqcnTZ3ilH              Alan Walker
# 3  1QgFLJ24l2fodb7SdGBVgy                    Kujah
# 4  6BRtWlr1VmsiPjIFnvg9Qv                 Krewella
#
#                      album_name                    track_name  popularity  \
# 0  AMNESIA (feat. Boy In Space)  AMNESIA (feat. Boy In Space)          47
# 1                        Trench           Nico and the Niners          69
# 2              Sing Me to Sleep              Sing Me to Sleep          63
# 3                   Broken Down                   Broken Down          31
# 4               New World Pt. 1                     Calm Down          43
#
#    duration_ms explicit danceability energy   key  ...  mode speechiness  \
# 0       175826    False         None   None  None  ...  None        None
# 1       225040    False         None   None  None  ...  None        None
# 2       189333    False         None   None  None  ...  None        None
# 3       145058    False         None   None  None  ...  None        None
# 4       190077     True         None   None  None  ...  None        None
#
#   acousticness instrumentalness liveness valence tempo time_signature  \
# 0         None             None     None    None  None           None
# 1         None             None     None    None  None           None
# 2         None             None     None    None  None           None
# 3         None             None     None    None  None           None
# 4         None             None     None    None  None           None
#
#     track_genre track_youtube_id
# 0           NaN             None
# 1           NaN             None
# 2           NaN             None
# 3           NaN             None
# 4  edm, dubstep             None
#
# [5 rows x 21 columns]
